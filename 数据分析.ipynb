# %%
import pandas as pd

# 构造DataFrame -- 创建数据集（学员成绩信息）
df = pd.DataFrame([
    {"姓名": "小王", "语文": 90, "数学": 90, "英语": 80},
    {"姓名": "小李", "语文": 85, "数学": 92, "英语": 78},
    {"姓名": "小张", "语文": 78, "数学": 88, "英语": 95},
    {"姓名": "小刘", "语文": 92, "数学": 85, "英语": 87},
    {"姓名": "小陈", "语文": 88, "数学": 79, "英语": 90},
    {"姓名": "小赵", "语文": 76, "数学": 94, "英语": 82},
    {"姓名": "小周", "语文": 95, "数学": 88, "英语": 91},
    {"姓名": "小吴", "语文": 82, "数学": 84, "英语": 79},
    {"姓名": "小郑", "语文": 89, "数学": 93, "英语": 86},
    {"姓名": "小黄", "语文": 91, "数学": 87, "英语": 84}
])

# 统计计算
print(f"语文最高分: {df["语文"].max()}, 最低分：{df["语文"].min():.2f}, 平均分：{df['语文'].mean()}")
print(f"数学最高分: {df["数学"].max()}, 最低分：{df["数学"].min():.2f}, 平均分：{df['数学'].mean()}")
print(f"英语最高分: {df["英语"].max()}, 最低分：{df["英语"].min():.2f}, 平均分：{df['英语'].mean()}")

print(df.index)
print(df.columns)
print(df.values)
print(df.dtypes)
print(df.size)
print(df.shape)
# Out:
# 语文最高分: 95, 最低分：76.00, 平均分：86.6
# 数学最高分: 94, 最低分：79.00, 平均分：88.0
# 英语最高分: 95, 最低分：78.00, 平均分：85.2
# RangeIndex(start=0, stop=10, step=1)
# Index(['姓名', '语文', '数学', '英语'], dtype='object')
# [['小王' 90 90 80]
#  ['小李' 85 92 78]
#  ['小张' 78 88 95]
#  ['小刘' 92 85 87]
#  ['小陈' 88 79 90]
#  ['小赵' 76 94 82]
#  ['小周' 95 88 91]
#  ['小吴' 82 84 79]
#  ['小郑' 89 93 86]
#  ['小黄' 91 87 84]]
# 姓名    object
# 语文     int64
# 数学     int64
# 英语     int64
# dtype: object
# 40
# (10, 4)

# %%
df4 = pd.DataFrame([
    ['张三', 85, 92, 78],
    ['李四', 78, 88, 95],
    ['王五', 92, 96, 89],
], columns = ['姓名', '语文', '数学', '英语'], index = ['a', 'b', 'c'])

print(df4)
print(df4.index)
print(df4.columns)
print(df4.values)
print(df4.dtypes)
print(df4.size)
print(df4.shape)

# %%
import pandas as pd

df = pd.DataFrame([
    {"姓名": "小王", "语文": 90, "数学": 90, "英语": 80},
    {"姓名": "小李", "语文": 85, "数学": 92, "英语": 78},
    {"姓名": "小张", "语文": 78, "数学": 88, "英语": 95},
    {"姓名": "小刘", "语文": 92, "数学": 85, "英语": 87},
    {"姓名": "小陈", "语文": 88, "数学": 79, "英语": 90},
    {"姓名": "小赵", "语文": 76, "数学": 94, "英语": 82},
    {"姓名": "小周", "语文": 95, "数学": 88, "英语": 91},
    {"姓名": "小吴", "语文": 82, "数学": 84, "英语": 79},
    {"姓名": "小郑", "语文": 89, "数学": 93, "英语": 86},
    {"姓名": "小黄", "语文": 91, "数学": 87, "英语": 84}
])

# DataFrame 常见属性 - index, columns, values, size, dtypes,shape
print(df.index.tolist())  # index ： 索引
print(df.columns.tolist())    # columns : 列名
print(df4.values)   # values : 值
print(df.size)  #size : 元素个数
print(df.dtypes)  # dtypes : 数据类型
print(df.shape)   #  shape : 维度（行，列）

# %%
# Series

s1 = pd.Series([10, 20, 30 ,40 ,50])

s2 = pd.Series((10, 20, 30, 40, 50), index=['a', 'b', 'c', 'd', 'e'])

s3 = pd.Series({'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50})

s4 = df['语文']

s5 = df4['数学']

# Series  常见属性 - index, values, size, dtype ,shape
print(s3.index.tolist())    # index : 索引
print(s3.values.tolist())   # values : 值
print(s3.size)              # size : 元素个数
print(s3.dtype)             # dtype : 数据类型
print(s3.shape)             # shape : 维度（行，）
